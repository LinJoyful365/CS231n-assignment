# %% [markdown]
# # Multi-Layer Fully Connected Network
# In this exercise, you will implement a fully connected network with an arbitrary number of hidden layers.

# %% [markdown]
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the network initialization, forward pass, and backward pass. Throughout this assignment, you will be implementing layers in `cs231n/layers.py`. You can re-use your implementations for `affine_forward`, `affine_backward`, `relu_forward`, `relu_backward`, and `softmax_loss` from before. For right now, don't worry about implementing dropout or batch/layer normalization yet, as you will add those features later.

# %%
# Setup cell.
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # Set default size of plots.
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """Returns relative error."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR-10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(f"{k}: {v.shape}")
# Out:
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Initial Loss and Gradient Check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. This is a good way to see if the initial losses seem reasonable.
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
    print("Running check with reg = ", reg)
    model = FullyConnectedNet(
        [H1, H2],
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2,
        dtype=np.float64
    )

    loss, grads = model.loss(X, y)
    print("Initial loss: ", loss)

    # Most of the errors should be on the order of e-7 or smaller.
    # NOTE: It is fine however to see an error for W2 on the order of e-5
    # for the check when reg = 0.0
    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print(f"{name} relative error: {rel_error(grad_num, grads[name])}")
# Out:
# Running check with reg =  0
# Initial loss:  2.300479089768492
# W1 relative error: 1.0252674374835853e-07
# W2 relative error: 2.2120479365657735e-05
# W3 relative error: 4.5623278853694277e-07
# b1 relative error: 4.660094280453673e-09
# b2 relative error: 2.085654276112763e-09
# b3 relative error: 1.689724888469736e-10
# Running check with reg =  3.14
# Initial loss:  7.052114776533016
# W1 relative error: 3.904542008453064e-09
# W2 relative error: 3.522821562176466e-08
# W3 relative error: 3.483989217647104e-08
# b1 relative error: 1.4752427836900184e-08
# b2 relative error: 1.7223750761525226e-09
# b3 relative error: 2.378772438198909e-10

# %% [markdown]
# As another sanity check, make sure your network can overfit on a small dataset of 50 images. First, we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

weight_scale = 1e-2   # Experiment with this!
learning_rate = 5e-3 # Experiment with this!


model = FullyConnectedNet(
    [100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=100,
    batch_size=25,
    update_rule="sgd",
    optim_config={"learning_rate": learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title("Training loss history")
plt.xlabel("Iteration")
plt.ylabel("Training loss")
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 200) loss: 2.297792
# (Epoch 0 / 100) train acc: 0.200000; val_acc: 0.101000
# (Epoch 1 / 100) train acc: 0.280000; val_acc: 0.106000
# (Epoch 2 / 100) train acc: 0.480000; val_acc: 0.124000
# (Epoch 3 / 100) train acc: 0.360000; val_acc: 0.108000
# (Epoch 4 / 100) train acc: 0.520000; val_acc: 0.114000
# (Epoch 5 / 100) train acc: 0.400000; val_acc: 0.120000
# (Iteration 11 / 200) loss: 1.450600
# (Epoch 6 / 100) train acc: 0.700000; val_acc: 0.138000
# (Epoch 7 / 100) train acc: 0.680000; val_acc: 0.160000
# (Epoch 8 / 100) train acc: 0.820000; val_acc: 0.199000
# (Epoch 9 / 100) train acc: 0.800000; val_acc: 0.172000
# (Epoch 10 / 100) train acc: 0.820000; val_acc: 0.175000
# (Iteration 21 / 200) loss: 0.885348
# (Epoch 11 / 100) train acc: 0.900000; val_acc: 0.168000
# (Epoch 12 / 100) train acc: 0.900000; val_acc: 0.182000
# (Epoch 13 / 100) train acc: 0.920000; val_acc: 0.167000
# (Epoch 14 / 100) train acc: 0.940000; val_acc: 0.177000
# (Epoch 15 / 100) train acc: 0.940000; val_acc: 0.177000
# (Iteration 31 / 200) loss: 0.219218
# (Epoch 16 / 100) train acc: 0.940000; val_acc: 0.174000
# (Epoch 17 / 100) train acc: 0.960000; val_acc: 0.171000
# (Epoch 18 / 100) train acc: 0.980000; val_acc: 0.184000
# (Epoch 19 / 100) train acc: 0.960000; val_acc: 0.185000
# (Epoch 20 / 100) train acc: 0.980000; val_acc: 0.168000
# (Iteration 41 / 200) loss: 0.097521
# (Epoch 21 / 100) train acc: 0.980000; val_acc: 0.181000
# (Epoch 22 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 23 / 100) train acc: 1.000000; val_acc: 0.175000
# (Epoch 24 / 100) train acc: 0.980000; val_acc: 0.171000
# (Epoch 25 / 100) train acc: 0.980000; val_acc: 0.179000
# (Iteration 51 / 200) loss: 0.188990
# (Epoch 26 / 100) train acc: 1.000000; val_acc: 0.181000
# (Epoch 27 / 100) train acc: 1.000000; val_acc: 0.181000
# (Epoch 28 / 100) train acc: 1.000000; val_acc: 0.177000
# (Epoch 29 / 100) train acc: 1.000000; val_acc: 0.178000
# (Epoch 30 / 100) train acc: 1.000000; val_acc: 0.176000
# (Iteration 61 / 200) loss: 0.036429
# (Epoch 31 / 100) train acc: 1.000000; val_acc: 0.177000
# (Epoch 32 / 100) train acc: 1.000000; val_acc: 0.187000
# (Epoch 33 / 100) train acc: 1.000000; val_acc: 0.188000
# (Epoch 34 / 100) train acc: 1.000000; val_acc: 0.176000
# (Epoch 35 / 100) train acc: 1.000000; val_acc: 0.175000
# (Iteration 71 / 200) loss: 0.036048
# (Epoch 36 / 100) train acc: 1.000000; val_acc: 0.178000
# (Epoch 37 / 100) train acc: 1.000000; val_acc: 0.173000
# (Epoch 38 / 100) train acc: 1.000000; val_acc: 0.177000
# (Epoch 39 / 100) train acc: 1.000000; val_acc: 0.175000
# (Epoch 40 / 100) train acc: 1.000000; val_acc: 0.176000
# (Iteration 81 / 200) loss: 0.018971
# (Epoch 41 / 100) train acc: 1.000000; val_acc: 0.178000
# (Epoch 42 / 100) train acc: 1.000000; val_acc: 0.180000
# (Epoch 43 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 44 / 100) train acc: 1.000000; val_acc: 0.178000
# (Epoch 45 / 100) train acc: 1.000000; val_acc: 0.181000
# (Iteration 91 / 200) loss: 0.018931
# (Epoch 46 / 100) train acc: 1.000000; val_acc: 0.180000
# (Epoch 47 / 100) train acc: 1.000000; val_acc: 0.179000
# (Epoch 48 / 100) train acc: 1.000000; val_acc: 0.181000
# (Epoch 49 / 100) train acc: 1.000000; val_acc: 0.180000
# (Epoch 50 / 100) train acc: 1.000000; val_acc: 0.184000
# (Iteration 101 / 200) loss: 0.012618
# (Epoch 51 / 100) train acc: 1.000000; val_acc: 0.183000
# (Epoch 52 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 53 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 54 / 100) train acc: 1.000000; val_acc: 0.180000
# (Epoch 55 / 100) train acc: 1.000000; val_acc: 0.185000
# (Iteration 111 / 200) loss: 0.009539
# (Epoch 56 / 100) train acc: 1.000000; val_acc: 0.180000
# (Epoch 57 / 100) train acc: 1.000000; val_acc: 0.180000
# (Epoch 58 / 100) train acc: 1.000000; val_acc: 0.188000
# (Epoch 59 / 100) train acc: 1.000000; val_acc: 0.185000
# (Epoch 60 / 100) train acc: 1.000000; val_acc: 0.184000
# (Iteration 121 / 200) loss: 0.012641
# (Epoch 61 / 100) train acc: 1.000000; val_acc: 0.184000
# (Epoch 62 / 100) train acc: 1.000000; val_acc: 0.183000
# (Epoch 63 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 64 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 65 / 100) train acc: 1.000000; val_acc: 0.183000
# (Iteration 131 / 200) loss: 0.012802
# (Epoch 66 / 100) train acc: 1.000000; val_acc: 0.181000
# (Epoch 67 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 68 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 69 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 70 / 100) train acc: 1.000000; val_acc: 0.184000
# (Iteration 141 / 200) loss: 0.009879
# (Epoch 71 / 100) train acc: 1.000000; val_acc: 0.184000
# (Epoch 72 / 100) train acc: 1.000000; val_acc: 0.185000
# (Epoch 73 / 100) train acc: 1.000000; val_acc: 0.186000
# (Epoch 74 / 100) train acc: 1.000000; val_acc: 0.185000
# (Epoch 75 / 100) train acc: 1.000000; val_acc: 0.186000
# (Iteration 151 / 200) loss: 0.005226
# (Epoch 76 / 100) train acc: 1.000000; val_acc: 0.185000
# (Epoch 77 / 100) train acc: 1.000000; val_acc: 0.186000
# (Epoch 78 / 100) train acc: 1.000000; val_acc: 0.187000
# (Epoch 79 / 100) train acc: 1.000000; val_acc: 0.184000
# (Epoch 80 / 100) train acc: 1.000000; val_acc: 0.182000
# (Iteration 161 / 200) loss: 0.004534
# (Epoch 81 / 100) train acc: 1.000000; val_acc: 0.181000
# (Epoch 82 / 100) train acc: 1.000000; val_acc: 0.184000
# (Epoch 83 / 100) train acc: 1.000000; val_acc: 0.185000
# (Epoch 84 / 100) train acc: 1.000000; val_acc: 0.183000
# (Epoch 85 / 100) train acc: 1.000000; val_acc: 0.184000
# (Iteration 171 / 200) loss: 0.006160
# (Epoch 86 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 87 / 100) train acc: 1.000000; val_acc: 0.183000
# (Epoch 88 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 89 / 100) train acc: 1.000000; val_acc: 0.185000
# (Epoch 90 / 100) train acc: 1.000000; val_acc: 0.183000
# (Iteration 181 / 200) loss: 0.004791
# (Epoch 91 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 92 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 93 / 100) train acc: 1.000000; val_acc: 0.183000
# (Epoch 94 / 100) train acc: 1.000000; val_acc: 0.182000
# (Epoch 95 / 100) train acc: 1.000000; val_acc: 0.181000
# (Iteration 191 / 200) loss: 0.003234
# (Epoch 96 / 100) train acc: 1.000000; val_acc: 0.180000
# (Epoch 97 / 100) train acc: 1.000000; val_acc: 0.179000
# (Epoch 98 / 100) train acc: 1.000000; val_acc: 0.183000
# (Epoch 99 / 100) train acc: 1.000000; val_acc: 0.185000
# (Epoch 100 / 100) train acc: 1.000000; val_acc: 0.184000

# %% [markdown]
# Now, try to use a five-layer network with 100 units on each layer to overfit on 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

learning_rate = 1e-2  # Experiment with this!
weight_scale = 5e-2   # Experiment with this!


model = FullyConnectedNet(
    [100, 100, 100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule='sgd',
    optim_config={'learning_rate': learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 4.395350
# (Epoch 0 / 20) train acc: 0.320000; val_acc: 0.155000
# (Epoch 1 / 20) train acc: 0.240000; val_acc: 0.095000
# (Epoch 2 / 20) train acc: 0.520000; val_acc: 0.144000
# (Epoch 3 / 20) train acc: 0.620000; val_acc: 0.131000
# (Epoch 4 / 20) train acc: 0.780000; val_acc: 0.127000
# (Epoch 5 / 20) train acc: 0.960000; val_acc: 0.147000
# (Iteration 11 / 40) loss: 0.291854
# (Epoch 6 / 20) train acc: 0.940000; val_acc: 0.152000
# (Epoch 7 / 20) train acc: 0.980000; val_acc: 0.151000
# (Epoch 8 / 20) train acc: 1.000000; val_acc: 0.145000
# (Epoch 9 / 20) train acc: 1.000000; val_acc: 0.141000
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.151000
# (Iteration 21 / 40) loss: 0.064072
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.152000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.154000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.151000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.157000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.151000
# (Iteration 31 / 40) loss: 0.033499
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.150000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.154000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.155000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.152000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.159000

# %% [markdown]
# ## Inline Question 1:
# Did you notice anything about the comparative difficulty of training the three-layer network vs. training the five-layer network? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# ## Answer:
# 现象： 五层网络比三层网络更难训练，且对初始化高度敏感。
#
# 原因： 因为误差和信号在深层网络中是按指数级传播的。微小的初始化偏差在经过更多层的矩阵乘法和非线性激活后，会被剧烈放大，从而引发梯度消失或梯度爆炸。

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {"learning_rate": 1e-3, "velocity": v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print("next_w error: ", rel_error(next_w, expected_next_w))
print("velocity error: ", rel_error(expected_velocity, config["velocity"]))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )

    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': 5e-3},
        verbose=True,
    )
    solvers[update_rule] = solver
    solver.train()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"loss_{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"train_acc_{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"val_acc_{update_rule}")

for ax in axes:
    ax.legend(loc="best", ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  sgd
# (Iteration 1 / 200) loss: 2.819002
# (Epoch 0 / 5) train acc: 0.098000; val_acc: 0.103000
# (Iteration 11 / 200) loss: 2.298021
# (Iteration 21 / 200) loss: 2.242765
# (Iteration 31 / 200) loss: 2.154099
# (Epoch 1 / 5) train acc: 0.230000; val_acc: 0.180000
# (Iteration 41 / 200) loss: 2.141011
# (Iteration 51 / 200) loss: 2.173340
# (Iteration 61 / 200) loss: 2.163939
# (Iteration 71 / 200) loss: 2.023477
# (Epoch 2 / 5) train acc: 0.267000; val_acc: 0.245000
# (Iteration 81 / 200) loss: 2.087823
# (Iteration 91 / 200) loss: 1.946061
# (Iteration 101 / 200) loss: 1.944696
# (Iteration 111 / 200) loss: 1.921219
# (Epoch 3 / 5) train acc: 0.285000; val_acc: 0.258000
# (Iteration 121 / 200) loss: 1.870482
# (Iteration 131 / 200) loss: 1.805901
# (Iteration 141 / 200) loss: 1.935036
# (Iteration 151 / 200) loss: 1.977601
# (Epoch 4 / 5) train acc: 0.351000; val_acc: 0.259000
# (Iteration 161 / 200) loss: 1.774357
# (Iteration 171 / 200) loss: 1.776175
# (Iteration 181 / 200) loss: 1.791328
# (Iteration 191 / 200) loss: 1.688699
# (Epoch 5 / 5) train acc: 0.362000; val_acc: 0.286000
# Running with  sgd_momentum
# (Iteration 1 / 200) loss: 2.561074
# (Epoch 0 / 5) train acc: 0.115000; val_acc: 0.092000
# (Iteration 11 / 200) loss: 2.136256
# (Iteration 21 / 200) loss: 2.029728
# (Iteration 31 / 200) loss: 1.978848
# (Epoch 1 / 5) train acc: 0.310000; val_acc: 0.294000
# (Iteration 41 / 200) loss: 1.908037
# (Iteration 51 / 200) loss: 1.666057
# (Iteration 61 / 200) loss: 1.629584
# (Iteration 71 / 200) loss: 1.727094
# (Epoch 2 / 5) train acc: 0.406000; val_acc: 0.330000
# (Iteration 81 / 200) loss: 1.667505
# (Iteration 91 / 200) loss: 1.550734
# (Iteration 101 / 200) loss: 1.418951
# (Iteration 111 / 200) loss: 1.475659
# (Epoch 3 / 5) train acc: 0.442000; val_acc: 0.351000
# (Iteration 121 / 200) loss: 1.412387
# (Iteration 131 / 200) loss: 1.659937
# (Iteration 141 / 200) loss: 1.511216
# (Iteration 151 / 200) loss: 1.668219
# (Epoch 4 / 5) train acc: 0.466000; val_acc: 0.340000
# (Iteration 161 / 200) loss: 1.458914
# (Iteration 171 / 200) loss: 1.463443
# (Iteration 181 / 200) loss: 1.267850
# (Iteration 191 / 200) loss: 1.284018
# (Epoch 5 / 5) train acc: 0.564000; val_acc: 0.373000

# %% [markdown]
# ## RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism), not the first simplified version mentioned in the course notes.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  9.524687511038133e-08
# cache error:  2.6477955807156126e-09

# %%
# Test Adam implementation
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))
# Out:
# next_w error:  1.1395691798535431e-07
# v error:  4.208314038113071e-09
# m error:  4.214963193114416e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )
    solver = Solver(
        model,
        small_data,
        num_epochs=20,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': learning_rates[update_rule]},
        verbose=True
    )
    solvers[update_rule] = solver
    solver.train()
    print()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"{update_rule}")

for ax in axes:
    ax.legend(loc='best', ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  adam
# (Iteration 1 / 800) loss: 2.483950
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.146000
# (Iteration 11 / 800) loss: 2.057153
# (Iteration 21 / 800) loss: 1.881106
# (Iteration 31 / 800) loss: 1.801920
# (Epoch 1 / 20) train acc: 0.365000; val_acc: 0.314000
# (Iteration 41 / 800) loss: 1.671325
# (Iteration 51 / 800) loss: 1.675238
# (Iteration 61 / 800) loss: 1.753365
# (Iteration 71 / 800) loss: 1.638076
# (Epoch 2 / 20) train acc: 0.433000; val_acc: 0.344000
# (Iteration 81 / 800) loss: 1.518345
# (Iteration 91 / 800) loss: 1.513742
# (Iteration 101 / 800) loss: 1.608966
# (Iteration 111 / 800) loss: 1.390350
# (Epoch 3 / 20) train acc: 0.491000; val_acc: 0.347000
# (Iteration 121 / 800) loss: 1.366905
# (Iteration 131 / 800) loss: 1.273281
# (Iteration 141 / 800) loss: 1.247073
# (Iteration 151 / 800) loss: 1.184272
# (Epoch 4 / 20) train acc: 0.583000; val_acc: 0.382000
# (Iteration 161 / 800) loss: 1.426389
# (Iteration 171 / 800) loss: 1.252531
# (Iteration 181 / 800) loss: 1.203158
# (Iteration 191 / 800) loss: 1.106020
# (Epoch 5 / 20) train acc: 0.588000; val_acc: 0.359000
# (Iteration 201 / 800) loss: 1.052839
# (Iteration 211 / 800) loss: 1.107346
# (Iteration 221 / 800) loss: 1.212599
# (Iteration 231 / 800) loss: 0.870850
# (Epoch 6 / 20) train acc: 0.660000; val_acc: 0.389000
# (Iteration 241 / 800) loss: 0.892853
# (Iteration 251 / 800) loss: 1.050967
# (Iteration 261 / 800) loss: 0.864754
# (Iteration 271 / 800) loss: 1.083761
# (Epoch 7 / 20) train acc: 0.663000; val_acc: 0.355000
# (Iteration 281 / 800) loss: 0.874311
# (Iteration 291 / 800) loss: 0.767504
# (Iteration 301 / 800) loss: 0.801678
# (Iteration 311 / 800) loss: 0.789587
# (Epoch 8 / 20) train acc: 0.725000; val_acc: 0.373000
# (Iteration 321 / 800) loss: 1.028318
# (Iteration 331 / 800) loss: 0.927206
# (Iteration 341 / 800) loss: 0.810579
# (Iteration 351 / 800) loss: 0.656510
# (Epoch 9 / 20) train acc: 0.747000; val_acc: 0.374000
# (Iteration 361 / 800) loss: 1.033406
# (Iteration 371 / 800) loss: 0.737881
# (Iteration 381 / 800) loss: 0.689570
# (Iteration 391 / 800) loss: 0.742247
# (Epoch 10 / 20) train acc: 0.776000; val_acc: 0.393000
# (Iteration 401 / 800) loss: 0.808765
# (Iteration 411 / 800) loss: 0.814398
# (Iteration 421 / 800) loss: 0.691917
# (Iteration 431 / 800) loss: 0.732410
# (Epoch 11 / 20) train acc: 0.800000; val_acc: 0.382000
# (Iteration 441 / 800) loss: 0.793946
# (Iteration 451 / 800) loss: 0.583895
# (Iteration 461 / 800) loss: 0.445476
# (Iteration 471 / 800) loss: 0.359401
# (Epoch 12 / 20) train acc: 0.808000; val_acc: 0.389000
# (Iteration 481 / 800) loss: 0.507245
# (Iteration 491 / 800) loss: 0.586721
# (Iteration 501 / 800) loss: 0.496250
# (Iteration 511 / 800) loss: 0.620241
# (Epoch 13 / 20) train acc: 0.816000; val_acc: 0.392000
# (Iteration 521 / 800) loss: 0.590034
# (Iteration 531 / 800) loss: 0.568061
# (Iteration 541 / 800) loss: 0.396527
# (Iteration 551 / 800) loss: 0.542909
# (Epoch 14 / 20) train acc: 0.834000; val_acc: 0.393000
# (Iteration 561 / 800) loss: 0.410393
# (Iteration 571 / 800) loss: 0.601215
# (Iteration 581 / 800) loss: 0.419217
# (Iteration 591 / 800) loss: 0.585629
# (Epoch 15 / 20) train acc: 0.823000; val_acc: 0.380000
# (Iteration 601 / 800) loss: 0.750645
# (Iteration 611 / 800) loss: 0.441952
# (Iteration 621 / 800) loss: 0.523724
# (Iteration 631 / 800) loss: 0.288595
# (Epoch 16 / 20) train acc: 0.864000; val_acc: 0.351000
# (Iteration 641 / 800) loss: 0.539878
# (Iteration 651 / 800) loss: 0.630767
# (Iteration 661 / 800) loss: 0.515784
# (Iteration 671 / 800) loss: 0.465851
# (Epoch 17 / 20) train acc: 0.877000; val_acc: 0.366000
# (Iteration 681 / 800) loss: 0.425317
# (Iteration 691 / 800) loss: 0.287143
# (Iteration 701 / 800) loss: 0.231680
# (Iteration 711 / 800) loss: 0.385601
# (Epoch 18 / 20) train acc: 0.887000; val_acc: 0.379000
# (Iteration 721 / 800) loss: 0.439723
# (Iteration 731 / 800) loss: 0.248532
# (Iteration 741 / 800) loss: 0.253903
# (Iteration 751 / 800) loss: 0.365156
# (Epoch 19 / 20) train acc: 0.910000; val_acc: 0.379000
# (Iteration 761 / 800) loss: 0.274743
# (Iteration 771 / 800) loss: 0.343034
# (Iteration 781 / 800) loss: 0.308758
# (Iteration 791 / 800) loss: 0.414309
# (Epoch 20 / 20) train acc: 0.906000; val_acc: 0.375000
#
# Running with  rmsprop
# (Iteration 1 / 800) loss: 2.805654
# (Epoch 0 / 20) train acc: 0.106000; val_acc: 0.113000
# (Iteration 11 / 800) loss: 2.106578
# (Iteration 21 / 800) loss: 1.889117
# (Iteration 31 / 800) loss: 1.797571
# (Epoch 1 / 20) train acc: 0.352000; val_acc: 0.304000
# (Iteration 41 / 800) loss: 1.755749
# (Iteration 51 / 800) loss: 1.766991
# (Iteration 61 / 800) loss: 1.743103
# (Iteration 71 / 800) loss: 1.721155
# (Epoch 2 / 20) train acc: 0.455000; val_acc: 0.337000
# (Iteration 81 / 800) loss: 1.674263
# (Iteration 91 / 800) loss: 1.557348
# (Iteration 101 / 800) loss: 1.629264
# (Iteration 111 / 800) loss: 1.693561
# (Epoch 3 / 20) train acc: 0.463000; val_acc: 0.346000
# (Iteration 121 / 800) loss: 1.664755
# (Iteration 131 / 800) loss: 1.412544
# (Iteration 141 / 800) loss: 1.483384
# (Iteration 151 / 800) loss: 1.381497
# (Epoch 4 / 20) train acc: 0.503000; val_acc: 0.366000
# (Iteration 161 / 800) loss: 1.426949
# (Iteration 171 / 800) loss: 1.457247
# (Iteration 181 / 800) loss: 1.268024
# (Iteration 191 / 800) loss: 1.469703
# (Epoch 5 / 20) train acc: 0.547000; val_acc: 0.367000
# (Iteration 201 / 800) loss: 1.498690
# (Iteration 211 / 800) loss: 1.411210
# (Iteration 221 / 800) loss: 1.407158
# (Iteration 231 / 800) loss: 1.364292
# (Epoch 6 / 20) train acc: 0.586000; val_acc: 0.377000
# (Iteration 241 / 800) loss: 1.383254
# (Iteration 251 / 800) loss: 1.512230
# (Iteration 261 / 800) loss: 1.267848
# (Iteration 271 / 800) loss: 1.262184
# (Epoch 7 / 20) train acc: 0.580000; val_acc: 0.366000
# (Iteration 281 / 800) loss: 1.222643
# (Iteration 291 / 800) loss: 1.175460
# (Iteration 301 / 800) loss: 1.290002
# (Iteration 311 / 800) loss: 1.157178
# (Epoch 8 / 20) train acc: 0.646000; val_acc: 0.381000
# (Iteration 321 / 800) loss: 1.179670
# (Iteration 331 / 800) loss: 0.972242
# (Iteration 341 / 800) loss: 1.162749
# (Iteration 351 / 800) loss: 1.124295
# (Epoch 9 / 20) train acc: 0.647000; val_acc: 0.378000
# (Iteration 361 / 800) loss: 1.074262
# (Iteration 371 / 800) loss: 1.029686
# (Iteration 381 / 800) loss: 1.121793
# (Iteration 391 / 800) loss: 1.162733
# (Epoch 10 / 20) train acc: 0.650000; val_acc: 0.378000
# (Iteration 401 / 800) loss: 1.026729
# (Iteration 411 / 800) loss: 1.054583
# (Iteration 421 / 800) loss: 0.994123
# (Iteration 431 / 800) loss: 0.996116
# (Epoch 11 / 20) train acc: 0.671000; val_acc: 0.392000
# (Iteration 441 / 800) loss: 1.085214
# (Iteration 451 / 800) loss: 0.940449
# (Iteration 461 / 800) loss: 0.986248
# (Iteration 471 / 800) loss: 0.918143
# (Epoch 12 / 20) train acc: 0.736000; val_acc: 0.395000
# (Iteration 481 / 800) loss: 0.975239
# (Iteration 491 / 800) loss: 0.925031
# (Iteration 501 / 800) loss: 0.980178
# (Iteration 511 / 800) loss: 0.853076
# (Epoch 13 / 20) train acc: 0.747000; val_acc: 0.380000
# (Iteration 521 / 800) loss: 0.880908
# (Iteration 531 / 800) loss: 0.808066
# (Iteration 541 / 800) loss: 0.865914
# (Iteration 551 / 800) loss: 0.832501
# (Epoch 14 / 20) train acc: 0.739000; val_acc: 0.399000
# (Iteration 561 / 800) loss: 0.836394
# (Iteration 571 / 800) loss: 0.922783
# (Iteration 581 / 800) loss: 0.871774
# (Iteration 591 / 800) loss: 0.763349
# (Epoch 15 / 20) train acc: 0.779000; val_acc: 0.378000
# (Iteration 601 / 800) loss: 0.696128
# (Iteration 611 / 800) loss: 0.819358
# (Iteration 621 / 800) loss: 0.648429
# (Iteration 631 / 800) loss: 0.741250
# (Epoch 16 / 20) train acc: 0.758000; val_acc: 0.392000
# (Iteration 641 / 800) loss: 0.653995
# (Iteration 651 / 800) loss: 0.743585
# (Iteration 661 / 800) loss: 0.631382
# (Iteration 671 / 800) loss: 0.651460
# (Epoch 17 / 20) train acc: 0.792000; val_acc: 0.379000
# (Iteration 681 / 800) loss: 0.647012
# (Iteration 691 / 800) loss: 0.656981
# (Iteration 701 / 800) loss: 0.652861
# (Iteration 711 / 800) loss: 0.679412
# (Epoch 18 / 20) train acc: 0.810000; val_acc: 0.381000
# (Iteration 721 / 800) loss: 0.608198
# (Iteration 731 / 800) loss: 0.680600
# (Iteration 741 / 800) loss: 0.591172
# (Iteration 751 / 800) loss: 0.503479
# (Epoch 19 / 20) train acc: 0.830000; val_acc: 0.377000
# (Iteration 761 / 800) loss: 0.523408
# (Iteration 771 / 800) loss: 0.582547
# (Iteration 781 / 800) loss: 0.587529
# (Iteration 791 / 800) loss: 0.480656
# (Epoch 20 / 20) train acc: 0.862000; val_acc: 0.385000

# %% [markdown]
# ## Inline Question 2:
#
# AdaGrad, like Adam, is a per-parameter optimization method that uses the following update rule:
#
# ```
# cache += dw**2
# w += - learning_rate * dw / (np.sqrt(cache) + eps)
# ```
#
# John notices that when he was training a network with AdaGrad that the updates became very small, and that his network was learning slowly. Using your knowledge of the AdaGrad update rule, why do you think the updates would become very small? Would Adam have the same issue?
#
#
# ## Answer:
# 显然易见的是，由于cache是单调递增的，会导致步长的持续衰减
# Adam不会，这是因为 Adam（以及 RMSProp）引入了指数加权移动平均，而不是简单的累加。“记忆”是有期限的：Adam 不会无限制地累加所有历史梯度的平方。它使用一个衰减因子 $\beta_2$（通常为 0.999）来控制对旧梯度的遗忘程度：$$v_t = \beta_2 \cdot v_{t-1} + (1 - \beta_2) \cdot dw^2$$动态平衡：由于有了 $\beta_2$，二阶矩 $v_t$（相当于 AdaGrad 的 cache）反映的是近期梯度的幅值，而不是从第一步到现在的总和。

# %% [markdown]
# # Train a Good Model!
# Train the best fully connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully connected network.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the next assignment, we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional networks rather than fully connected networks.
#
# **Note:** In the next assignment, you will learn techniques like BatchNormalization and Dropout which can help you train powerful models.

# %%
best_model = None

################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
best_val = -1.0
best_cfg = None

# Stage 1: quick search on a subset for speed
search_data = {
    'X_train': data['X_train'][:10000],
    'y_train': data['y_train'][:10000],
    'X_val': data['X_val'],
    'y_val': data['y_val'],
}

candidate_configs = [
    dict(hidden_dims=[400, 200, 100], normalization='batchnorm', dropout_keep_ratio=1.0, reg=5e-4, weight_scale=2e-2, learning_rate=1e-3),
    dict(hidden_dims=[400, 200, 100], normalization='batchnorm', dropout_keep_ratio=1.0, reg=1e-3, weight_scale=2e-2, learning_rate=1e-3),
    dict(hidden_dims=[300, 150], normalization='batchnorm', dropout_keep_ratio=1.0, reg=5e-4, weight_scale=2e-2, learning_rate=1e-3),
    dict(hidden_dims=[400, 200, 100], normalization=None,       dropout_keep_ratio=1.0, reg=5e-4, weight_scale=1e-2, learning_rate=3e-4),
]

for i, cfg in enumerate(candidate_configs):
    print(f"[search {i+1}/{len(candidate_configs)}] {cfg}")
    model = FullyConnectedNet(
        hidden_dims=cfg['hidden_dims'],
        normalization=cfg['normalization'],
        dropout_keep_ratio=cfg['dropout_keep_ratio'],
        reg=cfg['reg'],
        weight_scale=cfg['weight_scale'],
        dtype=np.float32,
        seed=231,
    )

    solver = Solver(
        model,
        search_data,
        update_rule='adam',
        optim_config={'learning_rate': cfg['learning_rate']},
        lr_decay=0.95,
        num_epochs=8,
        batch_size=200,
        print_every=200,
        verbose=False,
    )
    solver.train()

    val_acc = solver.val_acc_history[-1]
    train_acc = solver.train_acc_history[-1]
    print(f"  train={train_acc:.4f}, val={val_acc:.4f}")

    if val_acc > best_val:
        best_val = val_acc
        best_cfg = cfg

print('best config from search:', best_cfg)
print('best val from search:', best_val)

# Stage 2: retrain best config on full training set
best_model = FullyConnectedNet(
    hidden_dims=best_cfg['hidden_dims'],
    normalization=best_cfg['normalization'],
    dropout_keep_ratio=best_cfg['dropout_keep_ratio'],
    reg=best_cfg['reg'],
    weight_scale=best_cfg['weight_scale'],
    dtype=np.float32,
    seed=231,
)

best_solver = Solver(
    best_model,
    data,
    update_rule='adam',
    optim_config={'learning_rate': best_cfg['learning_rate']},
    lr_decay=0.95,
    num_epochs=20,
    batch_size=200,
    print_every=200,
    verbose=True,
)
best_solver.train()

print('final best val accuracy:', max(best_solver.val_acc_history))



# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# [search 1/4] {'hidden_dims': [400, 200, 100], 'normalization': 'batchnorm', 'dropout_keep_ratio': 1.0, 'reg': 0.0005, 'weight_scale': 0.02, 'learning_rate': 0.001}
#   train=0.7830, val=0.4650
# [search 2/4] {'hidden_dims': [400, 200, 100], 'normalization': 'batchnorm', 'dropout_keep_ratio': 1.0, 'reg': 0.001, 'weight_scale': 0.02, 'learning_rate': 0.001}
#   train=0.7840, val=0.4600
# [search 3/4] {'hidden_dims': [300, 150], 'normalization': 'batchnorm', 'dropout_keep_ratio': 1.0, 'reg': 0.0005, 'weight_scale': 0.02, 'learning_rate': 0.001}
#   train=0.7360, val=0.4660
# [search 4/4] {'hidden_dims': [400, 200, 100], 'normalization': None, 'dropout_keep_ratio': 1.0, 'reg': 0.0005, 'weight_scale': 0.01, 'learning_rate': 0.0003}
#   train=0.7250, val=0.4530
# best config from search: {'hidden_dims': [300, 150], 'normalization': 'batchnorm', 'dropout_keep_ratio': 1.0, 'reg': 0.0005, 'weight_scale': 0.02, 'learning_rate': 0.001}
# best val from search: 0.466
# (Iteration 1 / 4900) loss: 2.415159
# (Epoch 0 / 20) train acc: 0.164000; val_acc: 0.191000
# (Iteration 201 / 4900) loss: 1.609019
# (Epoch 1 / 20) train acc: 0.481000; val_acc: 0.486000
# (Iteration 401 / 4900) loss: 1.330357
# (Epoch 2 / 20) train acc: 0.548000; val_acc: 0.494000
# (Iteration 601 / 4900) loss: 1.363105
# (Epoch 3 / 20) train acc: 0.563000; val_acc: 0.518000
# (Iteration 801 / 4900) loss: 1.351822
# (Epoch 4 / 20) train acc: 0.599000; val_acc: 0.528000
# (Iteration 1001 / 4900) loss: 1.268049
# (Iteration 1201 / 4900) loss: 1.238755
# (Epoch 5 / 20) train acc: 0.613000; val_acc: 0.530000
# (Iteration 1401 / 4900) loss: 1.198583
# (Epoch 6 / 20) train acc: 0.637000; val_acc: 0.534000
# (Iteration 1601 / 4900) loss: 1.094580
# (Epoch 7 / 20) train acc: 0.660000; val_acc: 0.554000
# (Iteration 1801 / 4900) loss: 1.039505
# (Epoch 8 / 20) train acc: 0.692000; val_acc: 0.566000
# (Iteration 2001 / 4900) loss: 1.055047
# (Iteration 2201 / 4900) loss: 1.137098
# (Epoch 9 / 20) train acc: 0.673000; val_acc: 0.541000
# (Iteration 2401 / 4900) loss: 1.034085
# (Epoch 10 / 20) train acc: 0.691000; val_acc: 0.524000
# (Iteration 2601 / 4900) loss: 0.893114
# (Epoch 11 / 20) train acc: 0.717000; val_acc: 0.556000
# (Iteration 2801 / 4900) loss: 0.861487
# (Epoch 12 / 20) train acc: 0.736000; val_acc: 0.571000
# (Iteration 3001 / 4900) loss: 0.912288
# (Epoch 13 / 20) train acc: 0.751000; val_acc: 0.535000
# (Iteration 3201 / 4900) loss: 0.963336
# (Iteration 3401 / 4900) loss: 0.994689
# (Epoch 14 / 20) train acc: 0.737000; val_acc: 0.538000
# (Iteration 3601 / 4900) loss: 0.837221
# (Epoch 15 / 20) train acc: 0.806000; val_acc: 0.565000
# (Iteration 3801 / 4900) loss: 0.847069
# (Epoch 16 / 20) train acc: 0.790000; val_acc: 0.551000
# (Iteration 4001 / 4900) loss: 0.846763
# (Epoch 17 / 20) train acc: 0.828000; val_acc: 0.563000
# (Iteration 4201 / 4900) loss: 0.703114
# (Iteration 4401 / 4900) loss: 0.844183
# (Epoch 18 / 20) train acc: 0.808000; val_acc: 0.558000
# (Iteration 4601 / 4900) loss: 0.777970
# (Epoch 19 / 20) train acc: 0.829000; val_acc: 0.550000
# (Iteration 4801 / 4900) loss: 0.640034
# (Epoch 20 / 20) train acc: 0.843000; val_acc: 0.551000
# final best val accuracy: 0.571

# %% [markdown]
# # Test Your Model!
# Run your best model on the validation and test sets. You should achieve at least 50% accuracy on the validation set and the test set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Validation set accuracy:  0.549
# Test set accuracy:  0.542
